# %% [markdown]
# ### Object oriented programming is about encapsulation and abstraction

# %%
class Person:
    def __init__(self): 
        self.name = 'joey'
        self._protected = 'protected'
#         self.__private = 'private'
        self.__lastname = 'Tribbiani'

    def PrintName(self):
        return self.name +' ' + self.__lastname

    def __hello(self):
        print('ssss')
    
    def access_to_hello(self):
        self.__hello()

#Outside class    
P = Person()

# %%
print(P.name)
# Out:
# joey

# %%
print(P.__lastname)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-1e58f4cca717> in <module>
# ----> 1 print(P.__lastname)
#
# AttributeError: 'Person' object has no attribute '__lastname'

# %%
P.__lastname = 'ssss'
print(P.__lastname)
# Out:
# ssss

# %%
print(P.PrintName())
# Out:
# joey Tribbiani

# %%
P._protected
# Out:
# 'protected'

# %%
P._protected = 'aa'
P._protected
# Out:
# 'aa'

# %%
P.__private
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-d1315a74a612> in <module>
# ----> 1 P.__private
#
# AttributeError: 'Person' object has no attribute '__private'

# %%
P._Person__lastname
# Out:
# 'Tribbiani'

# %%
print(P.__hello())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-51acbffa46a3> in <module>
# ----> 1 print(P.__hello())
#
# AttributeError: 'Person' object has no attribute '__hello'

# %%
P._Person__hello()

# %%
P.access_to_hello()
# Out:
# ssss

# %%
class Person:
    def __init__(self,name,lastname): 
        self.name = name
        self.__lastname = lastname

    def print_name(self):
        return self.name +' ' + self.__lastname
    
    def set_new_lastname(self,new_lastname):
        self.__lastname = new_lastname

# %%
p = Person('Joey','Tribbiani')
p.print_name()
# Out:
# 'Joey Tribbiani'

# %%
p = Person('joey','Tribbiani')
p.set_new_lastname('Bing')
p.print_name()
# Out:
# 'joey Bing'

# %%
p1 = Person('Joey','Tribbiani')
p1.print_name()
# Out:
# 'Joey Tribbiani'

# %%
p2 = Person('Monica','Geller')
p2.print_name()
# Out:
# 'Monica Geller'

# %%
p1.print_name()
# Out:
# 'Joey Tribbiani'

# %% [markdown]
# ### An example that shows you can search and find the answer

# %%
import glob
print(glob.glob('../*'))
# Out:
# ['../Day8', '../Day3', '../Day2', '../Day1', '../Day5', '../x.log', '../README.md', '../Day10', '../Day9', '../Day7', '../Day6', '../Day4', '../LICENSE']

# %% [markdown]
# #### Write down a function that returns attributes which do not begin with underline

# %%
p1 = Person('Joey','Tribbiani')

# %%
print(dir(Person))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'print_name', 'set_new_lastname']

# %%
print(dir(p1))
# Out:
# ['_Person__lastname', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'name', 'print_name', 'set_new_lastname']

# %%
callable(p1.print_name)
# Out:
# True

# %%
callable(p1.name)
# Out:
# False

# %%
type(p1.print_name)
# Out:
# method

# %%
type(p1.name)
# Out:
# str

# %% [markdown]
# ### Overriding

# %%
class Test():
    def noise(self):
        print('blahh blahh blahh')

# %%
test = Test()
test.noise()
# Out:
# blahh blahh blahh

# %%
class Test2(Test):
    def noise(self):
        print('I will not make noise!')

# %%
test = Test2()
test.noise()
# Out:
# I will not make noise!

# %% [markdown]
# ## Class vs. Instance

# %%
class Test1:
    var1 = 0
    
    def add(x,y):
        return x+y
    
    def addvar():
        Test1.var1 += 1

# %%
t1 = Test1()

# %%
t1.var1
# Out:
# 0

# %%
Test1.var1
# Out:
# 0

# %%
t1.add(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ce5219bf9901> in <module>
# ----> 1 t1.add(1,2)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
Test1.add(1,2)
# Out:
# 3

# %%
t1.addvar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-c60b654e393c> in <module>
# ----> 1 t1.addvar()
#
# TypeError: addvar() takes 0 positional arguments but 1 was given

# %%
Test1.addvar()

# %%
Test1.var1
# Out:
# 1

# %%
t1.var1
# Out:
# 1

# %%
class Classroom:
    n_student_of_school = 
    
    def add_new_student():

# %% [markdown]
# ### Example

# %%
class Email:
    def __init__(self):
        self.is_sent = False
    def send_email(self):
        self.is_sent = True

# %% [markdown]
# ### Another example

# %%
from numpy import mean

# %%
class Classroom:
    def __init__(self, name, teacher, makrs):
        self.name = name
        self.teacher = teacher
        self.makrs = makrs
        
    def average(self):
        print(mean(self.makrs))

# %%
classroom_1 = Classroom('A', 'Javad', [20,19,17,19,16])

# %%
classroom_1.average()
# Out:
# 18.2

# %%
classroom_2 = Classroom('B', 'Zahra', [20,19,17,19,16, 10, 11])

# %%
classroom_2.average()
# Out:
# 16.0

# %%
class Students:
    
    def __init__(self, name, teacher, makrs):
        self.name = name
        self.teacher = teacher
        self.makrs = makrs
        self.
        
    def average(self):
        print(mean(self.makrs))
        
    def add

# %%
class Test:
    var1 = 0
    def __init__(self):
        print('Test is initialized!')
        
        self.var3 = 3
#         Test.var1 += 1
        Test.add1()
    
    def fun1(self):
        print('this is fun 1')
        
    def fun2():
        print('this is fun 2')
    
    def add1():
        Test.var1 += 1

# %%
Test.var1
# Out:
# 0

# %%
Test.fun2()
# Out:
# this is fun 2

# %%
test1 = Test()
test2 = Test()
# Out:
# Test is initialized!
# Test is initialized!

# %%
test1.var3,test2.var3
# Out:
# (3, 3)

# %%
test1.var3 = 5

# %%
test1.var3,test2.var3
# Out:
# (5, 3)

# %%
test1.var1,test2.var1
# Out:
# (2, 2)
